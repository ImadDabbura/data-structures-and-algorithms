# %%
import numpy as np

# %% [markdown]
# # Selection Sort

# %%
def selection_sort(L):
    n = len(L)
    if n < 2:
        return
    for i in range(n - 1):
        smallest_idx = i
        for j in range(i + 1, n):
            if L[j] < L[smallest_idx]:
                smallest_idx = j
        if smallest_idx != i:
            L[smallest_idx], L[i] = L[i], L[smallest_idx]

# %%
L = list(np.random.randint(-100, 100, 10))
selection_sort(L)
L
# Out:
# [-53, -34, -30, 4, 16, 17, 25, 26, 79, 94]

# %% [markdown]
# Time complexity is __$O(n^2)$__ assuming comparisons can be done in constant time ($O(1)$). It does not use any extra memory.

# %% [markdown]
# # Bubble Sort

# %%
def bubble_sort(L):
    n = len(L)
    if n < 2:
        return
    for i in range(n - 1):
        for j in range(n - i - 1):
            if L[j] > L[j + 1]:
                L[j], L[j + 1] = L[j + 1], L[j]

# %%
L = list(np.random.randint(-100, 100, 10))
bubble_sort(L)
L
# Out:
# [-89, -70, -61, -58, -51, -50, -33, 20, 21, 86]

# %% [markdown]
# Time complexity is __$O(n^2)$__ assuming comparisons can be done in constant time ($O(1)$). It does not use any extra memory.

# %%
def improved_bubble_sort(L):
    n = len(L)
    if n < 2:
        return
    for i in range(n - 1):
        sorted_flag = True
        for j in range(n - i - 1):
            if L[j] > L[j + 1]:
                L[j], L[j + 1] = L[j + 1], L[j]
                sorted_flag = False
        if sorted_flag: # The array is already sorted
            break

# %%
L = list(np.random.randint(-100, 100, 10))
improved_bubble_sort(L)
L
# Out:
# [-99, -92, -79, -37, -20, 4, 4, 31, 60, 72]

# %% [markdown]
# Time complexity is __$O(n)$__ in the best case when the colloection is sorted; however, the average and worst case is __$O(n^2)$__.

# %% [markdown]
# # Insertion Sort

# %%
 def insertion_sort(L):
    n = len(L)
    if n < 2:
        return
    for i in range(1, n):
        key = L[i]
        j = i
        while j > 0 and key < L[j - 1]:
            L[j] = L[j - 1]
            j -= 1
        L[j] = key

# %%
L = list(np.random.randint(-100, 100, 10))
insertion_sort(L)
L
# Out:
# [-60, -53, -37, -32, -29, -25, -3, 11, 27, 84]

# %% [markdown]
# Time complexity is __$O(n)$__ in the best case when the colloection is sorted; however, the average and worst case is __$O(n^2)$__.

# %% [markdown]
# # Merge Sort

# %%
def merge(left, right, L):
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            L[i + j] = left[i]
            i += 1
        else:
            L[i + j] = right[j]
            j += 1
    while i < len(left):
        L[i + j] = left[i]
        i += 1
    while j < len(right):
        L[i + j] = right[j]
        j += 1

def merge_sort(L):
    n = len(L)
    if n < 2:
        return
    # divide
    mid = n // 2
    left = L[:mid]
    right = L[mid:]
    # concquer
    merge_sort(left)
    merge_sort(right)
    merge(left, right, L)

# %%
L = list(np.random.randint(-100, 100, 10))
merge_sort(L)
L
# Out:
# [-95, -95, -85, -84, -55, -39, 24, 61, 82, 89]

# %% [markdown]
# Time complexity is __$O(nlogn)$__ in the worst case. Also, this is not an inplace sorting algorithm and it will take __$O(n)$__ extra memory for all the sub-lists.

# %% [markdown]
# # Quick Sort

# %% [markdown]
# Time complexity is __$O(n^2)$__ in the worst case. However, we can get an average case of __$O(nlogn)$__ if we use randomized pivot. It is very widely used in practice due to its high efficiency with high probability. The worst case may happen when the array is already sorted or it is all duplicates.

# %%
def quick_sort(L):
    n = len(L)
    if n < 2:
        return L
    L = list(L)
    pivot = np.random.choice(L)
    L.remove(pivot)
    left = [e for e in L if e <= pivot]
    right = [e for e in L if e > pivot]
    return quick_sort(left) + [pivot] + quick_sort(right)

# %%
L = list(np.random.randint(-100, 100, 10))
quick_sort(L)
# Out:
# [-93, -84, -82, -81, -61, -30, -22, 23, 92, 98]

# %% [markdown]
# # Counting Sort

# %%
def count_sort(L, k):
    n = len(L)
    count = [0] * (k + 1)
    
    # count number of elements equal to index i
    for e in L:
        count[e] += 1
    
    # cal. cum sum; now count[i] has number of elements <= i
    for i in range(1, k + 1):
        count[i] += count[i - 1]
    
    # Copy elements to output array
    output = [0] * n
    for e in L:
        output[count[e] - 1] = e
        count[e] -= 1
    return output

# %%
L = [2, 5, 3, 0, 2, 3, 0, 3]
count_sort(L, 5)
# Out:
# [0, 0, 2, 2, 3, 3, 3, 5]

# %% [markdown]
# The running time is $O(n + k)$ which is linear as long as $k = n^{O(1)}$. Space complexity is $O(n + k)$. It works well with small range of integers.

# %% [markdown]
# # Bucket Sort

# %%
def bucket_sort(L, k):
    n = len(L)
    bucket = [[] for _ in range(k + 1)]
    for e in L:
        bucket[e].append(e)
    output = [0] * n
    i = 0
    for k in bucket:
        for e in k:
            output[i] = e
            i += 1
    return output

# %%
L = [2, 5, 3, 0, 2, 3, 0, 3]
bucket_sort(L, 5)
# Out:
# [0, 0, 2, 2, 3, 3, 3, 5]

# %% [markdown]
# The running time is $O(n + k)$ which is linear as long as $k = n^{O(1)}$. Space complexity is $O(n + k)$. It works well with small range of integers.

# %% [markdown]
# # Heap Sort

# %%
class HeapSort:
    @staticmethod
    def sort(arr):
        n = len(arr)
        HeapSort._heapify(arr)
        for i in range(1, n):
            HeapSort._swap(arr, 0, n - i)
            HeapSort._downheap(arr, 0, n - i)
    
    @staticmethod
    def _swap(arr, i, j):
        arr[i], arr[j] = arr[j], arr[i]
    
    @staticmethod
    def _heapify(arr):
        n = len(arr)
        parent = (n - 1) // 2
        for i in range(parent, -1, -1):
            HeapSort._downheap(arr, i, n)
    
    @staticmethod
    def _downheap(arr, i, j):
        if (2 * i) + 1 < j:
            child = left = (2 * i) + 1
            if (2 * i) + 2 < j:
                right = (2 * i) + 2
                if arr[right] < arr[left]:
                    child = right
            if arr[child] < arr[i]:
                HeapSort._swap(arr, i, child)
                HeapSort._downheap(arr, child, j)

# %%
L = list(np.random.randint(-100, 100, 10))
HeapSort.sort(L)
L, L[::-1]
# Out:
# ([91, 60, 51, -25, -29, -41, -49, -68, -79, -96],
#  [-96, -79, -68, -49, -41, -29, -25, 51, 60, 91])

# %% [markdown]
# The running time is $O(nlogn)$.

# %% [markdown]
# # Randomized Quick Select

# %%
def quick_select(S, k):
    n = len(S)
    if n == 1:
        return S[0]
    pivot = np.random.choice(S)
    L = [e for e in S if e < pivot]
    E = [e for e in S if e == pivot]
    G = [e for e in S if e > pivot]
    
    if k <= len(L):
        return quick_select(L, k)
    elif k <= len(L) + len(E):
        return pivot
    else:
        j = k - len(L) - len(E)
        return quick_select(G, j)

# %%
for i in range(1000):
    try:
        k = np.random.randint(1, 11, 1)[0]
        quick_select(np.random.randint(-100, 100, 10), k)
    except:
        print('failed')

# %% [markdown]
# It has expected run time of $O(n)$; however, the worst case running time is $O(n^2)$.

# %% [markdown]
# # Sorting Summary

# %% [markdown]
# <img src="sorting_summary.png">
